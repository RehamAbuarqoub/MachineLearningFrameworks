# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Step 1: Generate synthetic regression data
X, y = make_regression(n_samples=200, n_features=2, noise=20, random_state=42)

# Step 2: Feature scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Step 3: Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Step 4: Initialize and fit KNN Regressor with k=7
knn = KNeighborsRegressor(n_neighbors=7)
knn.fit(X_train, y_train)

# Step 5: Make predictions
y_pred = knn.predict(X_test)

# Step 6: Evaluate model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", round(mse, 2))
print("R² Score:", round(r2, 2))

# Step 7: Plot predictions vs actual
plt.figure(figsize=(6, 6))
plt.scatter(y_test, y_pred, color='green', alpha=0.6, label='Predicted vs Actual')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', label='Ideal Fit')
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("KNN Regression (k=7) - Actual vs Predicted")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Mean Squared Error: 766.11
# R² Score: 0.78

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Step 1: Generate synthetic regression data
X, y = make_regression(n_samples=200, n_features=2, noise=20, random_state=42)

# Step 2: Normalize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Step 3: Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Step 4: Initialize and train the Decision Tree Regressor
model = DecisionTreeRegressor(random_state=42)
model.fit(X_train, y_train)

# Step 5: Make predictions on the test set
y_pred = model.predict(X_test)

# Step 6: Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", round(mse, 2))
print("R² Score:", round(r2, 2))

# Step 7: Visualize predictions vs actual values
plt.figure(figsize=(6, 6))
plt.scatter(y_test, y_pred, color='orange', alpha=0.6, label='Predicted vs Actual')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', label='Ideal Fit')
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Decision Tree Regression - Actual vs Predicted")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Mean Squared Error: 852.69
# R² Score: 0.75

# %% [markdown]
# ## Three Main points:
#
#
# ### 1. Model Behavior and Interpretability
# Decision Tree creates rules by recursively splitting the feature space; it’s easy to interpret and can capture non-linear patterns well, but is prone to overfitting, especially with small datasets.
#
# KNN makes predictions based on the average of the nearest k neighbors; it’s simple and non-parametric, but performance heavily depends on the choice of k and the data scaling.
#
# Both models were trained on the same normalized synthetic dataset with 2 features, so it's a fair comparison.
# ### 2. Performance Evaluation (MSE & R² Score)
# Use the Mean Squared Error (MSE) and R² Score to compare their predictive performance.
#
# MSE gives an idea of average error magnitude.
#
# R² indicates how well the model explains the variance in the target variable (closer to 1 is better).
#
# You can mention which model had the lower MSE and higher R² and interpret which one performed better on this dataset.
# ### 3. Visual Interpretation of Results
# In both plots, the red line shows the ideal case where predictions match actual values perfectly.
#
# The scatter of points around this line tells you how close predictions were.
#
# If the points are tightly clustered around the red line, the model performed well.
#
# Mention any visible differences in scatter pattern between the Decision Tree and KNN predictions — e.g., one may have more extreme errors or be more consistently close to the ideal line.
